# %%
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import gymnasium as gym
import imageio
from collections import deque
from IPython.display import Video
from numba import jit
from random import random, randint, sample

from tetris_gymnasium.envs.tetris import Tetris
from tetris_gymnasium.wrappers.grouped import GroupedActionsObservations
from tetris_gymnasium.mappings.rewards import RewardsMapping

# %%
def make_custom_tetris_env(
    alife=1,
    clear_line=1,
    game_over=0,
    invalid_action=-1,
    render_mode=None
):

    # Create custom reward map
    custom_map = RewardsMapping(
        alife=alife,
        clear_line=clear_line,
        game_over=game_over,
        invalid_action=invalid_action
    )

    # Initialize env with reward override
    env = gym.make(
        "tetris_gymnasium/Tetris",
        rewards_mapping=custom_map,
        render_mode=render_mode  # Uncomment if needed
    )
    
    env = GroupedActionsObservations(env)
    
    return env

# %%
@jit(nopython=True)
def calculate_features_numba(inner_boards, lines_cleared_norm):
    """
    JIT-compiled feature calculation
    """
    num_actions, rows, cols = inner_boards.shape
    features = np.zeros((num_actions, 4), dtype=np.float32)
    
    for i in range(num_actions):
        board = inner_boards[i]
        
        # Heights
        heights = np.zeros(cols, dtype=np.int32)
        for col in range(cols):
            for row in range(rows):
                if board[row, col] != 0:
                    heights[col] = rows - row
                    break
        
        agg_height = np.sum(heights)
        
        # Holes
        holes = 0
        for col in range(cols):
            found_surface = False
            for row in range(rows):
                if board[row, col] != 0:
                    found_surface = True
                elif found_surface:
                    holes += 1
        
        # Bumpiness
        bumpiness = 0
        for col in range(cols - 1):
            bumpiness += abs(heights[col] - heights[col + 1])
        
        features[i] = [
            agg_height,
            lines_cleared_norm,
            holes,
            bumpiness
        ]
    
    return features

def extract_features_from_observations(board_state, info):
    """
    Numba-accelerated version
    """
    # Batch extract inner boards
    inner_boards = board_state[:, :-4, 4:-4]
    
    if isinstance(inner_boards, torch.Tensor):
        inner_boards = inner_boards.cpu().numpy()
    
    inner_boards = np.where(inner_boards == 1, 0, inner_boards)
    
    # JIT-compiled feature calculation
    features = calculate_features_numba(inner_boards, info["lines_cleared"] / 4.0)
    
    return torch.from_numpy(features)

@jit(nopython=True)
def calculate_features_numba_single(inner_boards, lines_cleared_norm):
    """
    JIT-compiled feature calculation
    """
    rows, cols = inner_boards.shape
    
    features = []
    
    board = inner_boards
        
    # Heights
    heights = np.zeros(cols, dtype=np.int32)
    for col in range(cols):
        for row in range(rows):
            if board[row, col] != 0:
                heights[col] = rows - row
                break
    
    agg_height = np.sum(heights)
    
    # Holes
    holes = 0
    for col in range(cols):
        found_surface = False
        for row in range(rows):
            if board[row, col] != 0:
                found_surface = True
            elif found_surface:
                holes += 1
    
    # Bumpiness
    bumpiness = 0
    for col in range(cols - 1):
        bumpiness += abs(heights[col] - heights[col + 1])
        
    features.append([agg_height, lines_cleared_norm, holes, bumpiness])
    
    return features

def extract_features_from_observations_single(board_state, info):
    """
    Numba-accelerated version
    """
    # Batch extract inner boards
    inner_boards = board_state[:-4, 4:-4]

    
    if isinstance(inner_boards, torch.Tensor):
        inner_boards = inner_boards.cpu().numpy()
    
    inner_boards = np.where(inner_boards == 1, 0, inner_boards)
    
    # JIT-compiled feature calculation
    features = calculate_features_numba_single(inner_boards, info["lines_cleared"] / 4.0)
    
    return torch.from_numpy(np.array(features, dtype=np.float32))

# %%
import torch.nn as nn

class DQN_CNN(nn.Module):
    def __init__(self):
        super(DQN_CNN, self).__init__()

        self.conv1 = nn.Sequential(nn.Linear(4, 64), nn.ReLU(inplace=True))
        self.conv2 = nn.Sequential(nn.Linear(64, 64), nn.ReLU(inplace=True))
        self.conv3 = nn.Sequential(nn.Linear(64, 1))

        self._create_weights()

    def _create_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)

        return x

# %%
def train_dqn_cnn(episodes=3000, batch_size=512, gamma=0.99, lr=1e-4,
                   epsilon_initial=1.0, epsilon_min=1e-3, epsilon_decay=0.9985,
                   target_update=1000, replay_memory_size=30000, num_decay_epochs=2000):
    
    if torch.cuda.is_available():
        torch.cuda.manual_seed(123)
    else:
        torch.manual_seed(123)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    env = make_custom_tetris_env()
    DQN_Model = DQN_CNN().to(device)
    optimizer = torch.optim.Adam(DQN_Model.parameters(), lr=lr)
    criterion = nn.MSELoss()
    
    rewards_history = []
    lines_history = []

    replay_memory = deque(maxlen=replay_memory_size)
    for ep in range(episodes):
        state, info = env.reset()
        done = False
        
        features_before = torch.zeros(4, device='cuda:0')
        
        lines_cleared = 0
        total_reward = 0
        
        while not done:
            epsilon = epsilon_min + (max(num_decay_epochs - ep, 0) * (epsilon_initial - epsilon_min) / num_decay_epochs)

            # Extract normalized features for all possible placements
            # state shape: (40, 20, 10) -> features shape: (40, 4)
            features = extract_features_from_observations(state, info).to(device)
            
            DQN_Model.eval()
            with torch.no_grad():
                prediction = DQN_Model(features)[:, 0]  # Shape: (40,)
            DQN_Model.train()
            
            legal_actions = info.get('action_mask', None)
            if legal_actions is not None:
                if hasattr(legal_actions, 'numpy'):
                    legal_actions = legal_actions.numpy()
                legal_indices = np.where(legal_actions)[0]
                
                if np.random.rand() < epsilon:
                    # Explore: random legal action
                    action = np.random.choice(legal_indices)
                else:
                    # Exploit: best legal action
                    legal_tensor = torch.tensor(legal_actions, dtype=torch.bool, device=device)
                    masked_q_values = prediction.clone()
                    masked_q_values[~legal_tensor] = -float('inf')
                    action = masked_q_values.argmax().item()
            else:
                # No legal action masking
                if np.random.rand() < epsilon:
                    action = env.action_space.sample()
                else:
                    action = prediction.argmax().item()
        
            features_recommended = features[action, :]
            # features_current = extract_features_from_observations_single(state[action], info)
            # print("Before", features_before)
            # print("After", features_recommended)
            
            next_state, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated
            
            replay_memory.append([features_before, reward, features_recommended, done])
            
            features_before = features_recommended
            
            # if info["lines_cleared"] == 1:
            #     reward *= 10
            if info["lines_cleared"] == 2:
                reward *= 2
            elif info["lines_cleared"] == 3:
                reward *= 3
            elif info["lines_cleared"] >= 4:
                reward *= 4
            
            lines_cleared += info["lines_cleared"]
            total_reward += reward

            if len(replay_memory) < replay_memory_size / 10:
                continue
            batch = sample(replay_memory, min(len(replay_memory), batch_size))
            state_batch, reward_batch, next_state_batch, done_batch = zip(*batch)
            state_batch = torch.stack(tuple(state for state in state_batch))
            reward_batch = torch.from_numpy(np.array(reward_batch, dtype=np.float32)[:, None])
            next_state_batch = torch.stack(tuple(state for state in next_state_batch))
            
            if torch.cuda.is_available():
                state_batch = state_batch.cuda()
                reward_batch = reward_batch.cuda()
                next_state_batch = next_state_batch.cuda()

            q_values = DQN_Model(state_batch)
            DQN_Model.eval()
            with torch.no_grad():
                next_prediction_batch = DQN_Model(next_state_batch)
            DQN_Model.train()

            y_batch = torch.cat(
                tuple(reward if done else reward + gamma * prediction for reward, done, prediction in
                    zip(reward_batch, done_batch, next_prediction_batch)))[:, None]
            
            state = next_state
            
            optimizer.zero_grad()
            loss = criterion(q_values, y_batch)
            loss.backward()
            optimizer.step()
            
        rewards_history.append(total_reward)
        lines_history.append(lines_cleared)
        
        print(f"Episode {ep}, Total Reward: {total_reward:.2f}, Lines Cleared: {lines_cleared}, Epsilon: {epsilon:.3f}")
            
    return DQN_Model, rewards_history, lines_history

# %%
q_net, history, lines = train_dqn_cnn(episodes=2500)
# Out:
# Using device: cuda
# Episode 0, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 1.000
# Episode 1, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 1.000
# Episode 2, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.999
# Episode 3, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.999
# Episode 4, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.998
# Episode 5, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.998
# Episode 6, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.997
# Episode 7, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.997
# Episode 8, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.996
# Episode 9, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.996
# Episode 10, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.995
# Episode 11, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.995
# Episode 12, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.994
# Episode 13, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.994
# Episode 14, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.993
# Episode 15, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.993
# Episode 16, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.992
# Episode 17, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.992
# Episode 18, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.991
# Episode 19, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.991
# Episode 20, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.990
# Episode 21, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.990
# Episode 22, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.989
# Episode 23, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.989
# Episode 24, Total Reward: 12.00, Lines Cleared: 0, Epsilon: 0.988
# Episode 25, Total Reward: 10.00, Lines Cleared: 0, Epsilon: 0.988
# Episode 26, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.987
# Episode 27, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.987
# Episode 28, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.986
# Episode 29, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.986
# Episode 30, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.985
# Episode 31, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.985
# Episode 32, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.984
# Episode 33, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.984
# Episode 34, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.983
# Episode 35, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.983
# Episode 36, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.982
# Episode 37, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.982
# Episode 38, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.981
# Episode 39, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.981
# Episode 40, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.980
# Episode 41, Total Reward: 11.00, Lines Cleared: 0, Epsilon: 0.980
# Episode 42, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.979
# Episode 43, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.979
# Episode 44, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.978
# Episode 45, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.978
# Episode 46, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.977
# Episode 47, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.977
# Episode 48, Total Reward: 10.00, Lines Cleared: 0, Epsilon: 0.976
# Episode 49, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.976
# Episode 50, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.975
# Episode 51, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.975
# Episode 52, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.974
# Episode 53, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.974
# Episode 54, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.973
# Episode 55, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.973
# Episode 56, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.972
# Episode 57, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.972
# Episode 58, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.971
# Episode 59, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.971
# Episode 60, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.970
# Episode 61, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.970
# Episode 62, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.969
# Episode 63, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.969
# Episode 64, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.968
# Episode 65, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.968
# Episode 66, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.967
# Episode 67, Total Reward: 12.00, Lines Cleared: 0, Epsilon: 0.967
# Episode 68, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.966
# Episode 69, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.966
# Episode 70, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.965
# Episode 71, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.965
# Episode 72, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.964
# Episode 73, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.964
# Episode 74, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.963
# Episode 75, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.963
# Episode 76, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.962
# Episode 77, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.962
# Episode 78, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.961
# Episode 79, Total Reward: 45.00, Lines Cleared: 2, Epsilon: 0.961
# Episode 80, Total Reward: 10.00, Lines Cleared: 0, Epsilon: 0.960
# Episode 81, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.960
# Episode 82, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.959
# Episode 83, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.959
# Episode 84, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.958
# Episode 85, Total Reward: 11.00, Lines Cleared: 0, Epsilon: 0.958
# Episode 86, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.957
# Episode 87, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.957
# Episode 88, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.956
# Episode 89, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.956
# Episode 90, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.955
# Episode 91, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.955
# Episode 92, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.954
# Episode 93, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.954
# Episode 94, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.953
# Episode 95, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.953
# Episode 96, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.952
# Episode 97, Total Reward: 30.00, Lines Cleared: 1, Epsilon: 0.952
# Episode 98, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.951
# Episode 99, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.951
# Episode 100, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.950
# Episode 101, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.950
# Episode 102, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.949
# Episode 103, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.949
# Episode 104, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.948
# Episode 105, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.948
# Episode 106, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.947
# Episode 107, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.947
# Episode 108, Total Reward: 12.00, Lines Cleared: 0, Epsilon: 0.946
# Episode 109, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.946
# Episode 110, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.945
# Episode 111, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.945
# Episode 112, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.944
# Episode 113, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.944
# Episode 114, Total Reward: 12.00, Lines Cleared: 0, Epsilon: 0.943
# Episode 115, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.943
# Episode 116, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.942
# Episode 117, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.942
# Episode 118, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.941
# Episode 119, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.941
# Episode 120, Total Reward: 11.00, Lines Cleared: 0, Epsilon: 0.940
# Episode 121, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.940
# Episode 122, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.939
# Episode 123, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.939
# Episode 124, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.938
# Episode 125, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.938
# Episode 126, Total Reward: 8.00, Lines Cleared: 0, Epsilon: 0.937
# Episode 127, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.937
# Episode 128, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.936
# Episode 129, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.936
# Episode 130, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.935
# Episode 131, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.935
# Episode 132, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.934
# Episode 133, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.934
# Episode 134, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.933
# Episode 135, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.933
# Episode 136, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.932
# Episode 137, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.932
# Episode 138, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.931
# Episode 139, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.931
# Episode 140, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.930
# Episode 141, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.930
# Episode 142, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.929
# Episode 143, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.929
# Episode 144, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.928
# Episode 145, Total Reward: 11.00, Lines Cleared: 0, Epsilon: 0.928
# Episode 146, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.927
# Episode 147, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.927
# Episode 148, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.926
# Episode 149, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.926
# Episode 150, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.925
# Episode 151, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.925
# Episode 152, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.924
# Episode 153, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.924
# Episode 154, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.923
# Episode 155, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.923
# Episode 156, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.922
# Episode 157, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.922
# Episode 158, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.921
# Episode 159, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.921
# Episode 160, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.920
# Episode 161, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.920
# Episode 162, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.919
# Episode 163, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.919
# Episode 164, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.918
# Episode 165, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.918
# Episode 166, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.917
# Episode 167, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.917
# Episode 168, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.916
# Episode 169, Total Reward: 11.00, Lines Cleared: 0, Epsilon: 0.916
# Episode 170, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.915
# Episode 171, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.915
# Episode 172, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.914
# Episode 173, Total Reward: 10.00, Lines Cleared: 0, Epsilon: 0.914
# Episode 174, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.913
# Episode 175, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.913
# Episode 176, Total Reward: 10.00, Lines Cleared: 0, Epsilon: 0.912
# Episode 177, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.912
# Episode 178, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.911
# Episode 179, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.911
# Episode 180, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.910
# Episode 181, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.910
# Episode 182, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.909
# Episode 183, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.909
# Episode 184, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.908
# Episode 185, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.908
# Episode 186, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.907
# Episode 187, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.907
# Episode 188, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.906
# Episode 189, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.906
# Episode 190, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.905
# Episode 191, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.905
# Episode 192, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.904
# Episode 193, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.904
# Episode 194, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.903
# Episode 195, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.903
# Episode 196, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.902
# Episode 197, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.902
# Episode 198, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.901
# Episode 199, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.901
# Episode 200, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.900
# Episode 201, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.900
# Episode 202, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.899
# Episode 203, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.899
# Episode 204, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.898
# Episode 205, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.898
# Episode 206, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.897
# Episode 207, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.897
# Episode 208, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.896
# Episode 209, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.896
# Episode 210, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.895
# Episode 211, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.895
# Episode 212, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.894
# Episode 213, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.894
# Episode 214, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.893
# Episode 215, Total Reward: 11.00, Lines Cleared: 0, Epsilon: 0.893
# Episode 216, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.892
# Episode 217, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.892
# Episode 218, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.891
# Episode 219, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.891
# Episode 220, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.890
# Episode 221, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.890
# Episode 222, Total Reward: 10.00, Lines Cleared: 0, Epsilon: 0.889
# Episode 223, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.889
# Episode 224, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.888
# Episode 225, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.888
# Episode 226, Total Reward: 12.00, Lines Cleared: 0, Epsilon: 0.887
# Episode 227, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.887
# Episode 228, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.886
# Episode 229, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.886
# Episode 230, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.885
# Episode 231, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.885
# Episode 232, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.884
# Episode 233, Total Reward: 12.00, Lines Cleared: 0, Epsilon: 0.884
# Episode 234, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.883
# Episode 235, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.883
# Episode 236, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.882
# Episode 237, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.882
# Episode 238, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.881
# Episode 239, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.881
# Episode 240, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.880
# Episode 241, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.880
# Episode 242, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.879
# Episode 243, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.879
# Episode 244, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.878
# Episode 245, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.878
# Episode 246, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.877
# Episode 247, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.877
# Episode 248, Total Reward: 11.00, Lines Cleared: 0, Epsilon: 0.876
# Episode 249, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.876
# Episode 250, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.875
# Episode 251, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.875
# Episode 252, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.874
# Episode 253, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.874
# Episode 254, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.873
# Episode 255, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.873
# Episode 256, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.872
# Episode 257, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.872
# Episode 258, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.871
# Episode 259, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.871
# Episode 260, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.870
# Episode 261, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.870
# Episode 262, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.869
# Episode 263, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.869
# Episode 264, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.868
# Episode 265, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.868
# Episode 266, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.867
# Episode 267, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.867
# Episode 268, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.866
# Episode 269, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.866
# Episode 270, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.865
# Episode 271, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.865
# Episode 272, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.864
# Episode 273, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.864
# Episode 274, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.863
# Episode 275, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.863
# Episode 276, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.862
# Episode 277, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.862
# Episode 278, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.861
# Episode 279, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.861
# Episode 280, Total Reward: 11.00, Lines Cleared: 0, Epsilon: 0.860
# Episode 281, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.860
# Episode 282, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.859
# Episode 283, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.859
# Episode 284, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.858
# Episode 285, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.858
# Episode 286, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.857
# Episode 287, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.857
# Episode 288, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.856
# Episode 289, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.856
# Episode 290, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.855
# Episode 291, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.855
# Episode 292, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.854
# Episode 293, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.854
# Episode 294, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.853
# Episode 295, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.853
# Episode 296, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.852
# Episode 297, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.852
# Episode 298, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.851
# Episode 299, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.851
# Episode 300, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.850
# Episode 301, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.850
# Episode 302, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.849
# Episode 303, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.849
# Episode 304, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.848
# Episode 305, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.848
# Episode 306, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.847
# Episode 307, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.847
# Episode 308, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.846
# Episode 309, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.846
# Episode 310, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.845
# Episode 311, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.845
# Episode 312, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.844
# Episode 313, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.844
# Episode 314, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.843
# Episode 315, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.843
# Episode 316, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.842
# Episode 317, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.842
# Episode 318, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.841
# Episode 319, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.841
# Episode 320, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.840
# Episode 321, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.840
# Episode 322, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.839
# Episode 323, Total Reward: 11.00, Lines Cleared: 0, Epsilon: 0.839
# Episode 324, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.838
# Episode 325, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.838
# Episode 326, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.837
# Episode 327, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.837
# Episode 328, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.836
# Episode 329, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.836
# Episode 330, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.835
# Episode 331, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.835
# Episode 332, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.834
# Episode 333, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.834
# Episode 334, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.833
# Episode 335, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.833
# Episode 336, Total Reward: 26.00, Lines Cleared: 1, Epsilon: 0.832
# Episode 337, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.832
# Episode 338, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.831
# Episode 339, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.831
# Episode 340, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.830
# Episode 341, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.830
# Episode 342, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.829
# Episode 343, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.829
# Episode 344, Total Reward: 12.00, Lines Cleared: 0, Epsilon: 0.828
# Episode 345, Total Reward: 32.00, Lines Cleared: 0, Epsilon: 0.828
# Episode 346, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.827
# Episode 347, Total Reward: 41.00, Lines Cleared: 1, Epsilon: 0.827
# Episode 348, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.826
# Episode 349, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.826
# Episode 350, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.825
# Episode 351, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.825
# Episode 352, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.824
# Episode 353, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.824
# Episode 354, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.823
# Episode 355, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.823
# Episode 356, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.822
# Episode 357, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.822
# Episode 358, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.821
# Episode 359, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.821
# Episode 360, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.820
# Episode 361, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.820
# Episode 362, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.819
# Episode 363, Total Reward: 9.00, Lines Cleared: 0, Epsilon: 0.819
# Episode 364, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.818
# Episode 365, Total Reward: 10.00, Lines Cleared: 0, Epsilon: 0.818
# Episode 366, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.817
# Episode 367, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.817
# Episode 368, Total Reward: 12.00, Lines Cleared: 0, Epsilon: 0.816
# Episode 369, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.816
# Episode 370, Total Reward: 28.00, Lines Cleared: 0, Epsilon: 0.815
# Episode 371, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.815
# Episode 372, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.814
# Episode 373, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.814
# Episode 374, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.813
# Episode 375, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.813
# Episode 376, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.812
# Episode 377, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.812
# Episode 378, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.811
# Episode 379, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.811
# Episode 380, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.810
# Episode 381, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.810
# Episode 382, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.809
# Episode 383, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.809
# Episode 384, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.808
# Episode 385, Total Reward: 27.00, Lines Cleared: 0, Epsilon: 0.808
# Episode 386, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.807
# Episode 387, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.807
# Episode 388, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.806
# Episode 389, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.806
# Episode 390, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.805
# Episode 391, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.805
# Episode 392, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.804
# Episode 393, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.804
# Episode 394, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.803
# Episode 395, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.803
# Episode 396, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.802
# Episode 397, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.802
# Episode 398, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.801
# Episode 399, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.801
# Episode 400, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.800
# Episode 401, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.800
# Episode 402, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.799
# Episode 403, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.799
# Episode 404, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.798
# Episode 405, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.798
# Episode 406, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.797
# Episode 407, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.797
# Episode 408, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.796
# Episode 409, Total Reward: 32.00, Lines Cleared: 1, Epsilon: 0.796
# Episode 410, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.795
# Episode 411, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.795
# Episode 412, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.794
# Episode 413, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.794
# Episode 414, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.793
# Episode 415, Total Reward: 33.00, Lines Cleared: 1, Epsilon: 0.793
# Episode 416, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.792
# Episode 417, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.792
# Episode 418, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.791
# Episode 419, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.791
# Episode 420, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.790
# Episode 421, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.790
# Episode 422, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.789
# Episode 423, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.789
# Episode 424, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.788
# Episode 425, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.788
# Episode 426, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.787
# Episode 427, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.787
# Episode 428, Total Reward: 33.00, Lines Cleared: 1, Epsilon: 0.786
# Episode 429, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.786
# Episode 430, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.785
# Episode 431, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.785
# Episode 432, Total Reward: 28.00, Lines Cleared: 0, Epsilon: 0.784
# Episode 433, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.784
# Episode 434, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.783
# Episode 435, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.783
# Episode 436, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.782
# Episode 437, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.782
# Episode 438, Total Reward: 36.00, Lines Cleared: 1, Epsilon: 0.781
# Episode 439, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.781
# Episode 440, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.780
# Episode 441, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.780
# Episode 442, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.779
# Episode 443, Total Reward: 33.00, Lines Cleared: 1, Epsilon: 0.779
# Episode 444, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.778
# Episode 445, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.778
# Episode 446, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.777
# Episode 447, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.777
# Episode 448, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.776
# Episode 449, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.776
# Episode 450, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.775
# Episode 451, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.775
# Episode 452, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.774
# Episode 453, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.774
# Episode 454, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.773
# Episode 455, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.773
# Episode 456, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.772
# Episode 457, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.772
# Episode 458, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.771
# Episode 459, Total Reward: 33.00, Lines Cleared: 1, Epsilon: 0.771
# Episode 460, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.770
# Episode 461, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.770
# Episode 462, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.769
# Episode 463, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.769
# Episode 464, Total Reward: 33.00, Lines Cleared: 1, Epsilon: 0.768
# Episode 465, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.768
# Episode 466, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.767
# Episode 467, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.767
# Episode 468, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.766
# Episode 469, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.766
# Episode 470, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.765
# Episode 471, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.765
# Episode 472, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.764
# Episode 473, Total Reward: 32.00, Lines Cleared: 1, Epsilon: 0.764
# Episode 474, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.763
# Episode 475, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.763
# Episode 476, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.762
# Episode 477, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.762
# Episode 478, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.761
# Episode 479, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.761
# Episode 480, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.760
# Episode 481, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.760
# Episode 482, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.759
# Episode 483, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.759
# Episode 484, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.758
# Episode 485, Total Reward: 35.00, Lines Cleared: 1, Epsilon: 0.758
# Episode 486, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.757
# Episode 487, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.757
# Episode 488, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.756
# Episode 489, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.756
# Episode 490, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.755
# Episode 491, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.755
# Episode 492, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.754
# Episode 493, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.754
# Episode 494, Total Reward: 12.00, Lines Cleared: 0, Epsilon: 0.753
# Episode 495, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.753
# Episode 496, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.752
# Episode 497, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.752
# Episode 498, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.751
# Episode 499, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.751
# Episode 500, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.750
# Episode 501, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.750
# Episode 502, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.749
# Episode 503, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.749
# Episode 504, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.748
# Episode 505, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.748
# Episode 506, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.747
# Episode 507, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.747
# Episode 508, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.746
# Episode 509, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.746
# Episode 510, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.745
# Episode 511, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.745
# Episode 512, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.744
# Episode 513, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.744
# Episode 514, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.743
# Episode 515, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.743
# Episode 516, Total Reward: 30.00, Lines Cleared: 1, Epsilon: 0.742
# Episode 517, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.742
# Episode 518, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.741
# Episode 519, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.741
# Episode 520, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.740
# Episode 521, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.740
# Episode 522, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.739
# Episode 523, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.739
# Episode 524, Total Reward: 37.00, Lines Cleared: 1, Epsilon: 0.738
# Episode 525, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.738
# Episode 526, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.737
# Episode 527, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.737
# Episode 528, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.736
# Episode 529, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.736
# Episode 530, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.735
# Episode 531, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.735
# Episode 532, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.734
# Episode 533, Total Reward: 37.00, Lines Cleared: 1, Epsilon: 0.734
# Episode 534, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.733
# Episode 535, Total Reward: 27.00, Lines Cleared: 1, Epsilon: 0.733
# Episode 536, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.732
# Episode 537, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.732
# Episode 538, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.731
# Episode 539, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.731
# Episode 540, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.730
# Episode 541, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.730
# Episode 542, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.729
# Episode 543, Total Reward: 27.00, Lines Cleared: 1, Epsilon: 0.729
# Episode 544, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.728
# Episode 545, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.728
# Episode 546, Total Reward: 28.00, Lines Cleared: 0, Epsilon: 0.727
# Episode 547, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.727
# Episode 548, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.726
# Episode 549, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.726
# Episode 550, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.725
# Episode 551, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.725
# Episode 552, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.724
# Episode 553, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.724
# Episode 554, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.723
# Episode 555, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.723
# Episode 556, Total Reward: 30.00, Lines Cleared: 0, Epsilon: 0.722
# Episode 557, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.722
# Episode 558, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.721
# Episode 559, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.721
# Episode 560, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.720
# Episode 561, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.720
# Episode 562, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.719
# Episode 563, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.719
# Episode 564, Total Reward: 27.00, Lines Cleared: 0, Epsilon: 0.718
# Episode 565, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.718
# Episode 566, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.717
# Episode 567, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.717
# Episode 568, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.716
# Episode 569, Total Reward: 28.00, Lines Cleared: 0, Epsilon: 0.716
# Episode 570, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.715
# Episode 571, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.715
# Episode 572, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.714
# Episode 573, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.714
# Episode 574, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.713
# Episode 575, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.713
# Episode 576, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.712
# Episode 577, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.712
# Episode 578, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.711
# Episode 579, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.711
# Episode 580, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.710
# Episode 581, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.710
# Episode 582, Total Reward: 39.00, Lines Cleared: 1, Epsilon: 0.709
# Episode 583, Total Reward: 39.00, Lines Cleared: 1, Epsilon: 0.709
# Episode 584, Total Reward: 32.00, Lines Cleared: 1, Epsilon: 0.708
# Episode 585, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.708
# Episode 586, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.707
# Episode 587, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.707
# Episode 588, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.706
# Episode 589, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.706
# Episode 590, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.705
# Episode 591, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.705
# Episode 592, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.704
# Episode 593, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.704
# Episode 594, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.703
# Episode 595, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.703
# Episode 596, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.702
# Episode 597, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.702
# Episode 598, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.701
# Episode 599, Total Reward: 30.00, Lines Cleared: 1, Epsilon: 0.701
# Episode 600, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.700
# Episode 601, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.700
# Episode 602, Total Reward: 40.00, Lines Cleared: 1, Epsilon: 0.699
# Episode 603, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.699
# Episode 604, Total Reward: 29.00, Lines Cleared: 0, Epsilon: 0.698
# Episode 605, Total Reward: 46.00, Lines Cleared: 2, Epsilon: 0.698
# Episode 606, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.697
# Episode 607, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.697
# Episode 608, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.696
# Episode 609, Total Reward: 29.00, Lines Cleared: 1, Epsilon: 0.696
# Episode 610, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.695
# Episode 611, Total Reward: 30.00, Lines Cleared: 0, Epsilon: 0.695
# Episode 612, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.694
# Episode 613, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.694
# Episode 614, Total Reward: 40.00, Lines Cleared: 1, Epsilon: 0.693
# Episode 615, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.693
# Episode 616, Total Reward: 31.00, Lines Cleared: 1, Epsilon: 0.692
# Episode 617, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.692
# Episode 618, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.691
# Episode 619, Total Reward: 41.00, Lines Cleared: 1, Epsilon: 0.691
# Episode 620, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.690
# Episode 621, Total Reward: 37.00, Lines Cleared: 1, Epsilon: 0.690
# Episode 622, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.689
# Episode 623, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.689
# Episode 624, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.688
# Episode 625, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.688
# Episode 626, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.687
# Episode 627, Total Reward: 51.00, Lines Cleared: 2, Epsilon: 0.687
# Episode 628, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.686
# Episode 629, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.686
# Episode 630, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.685
# Episode 631, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.685
# Episode 632, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.684
# Episode 633, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.684
# Episode 634, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.683
# Episode 635, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.683
# Episode 636, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.682
# Episode 637, Total Reward: 41.00, Lines Cleared: 1, Epsilon: 0.682
# Episode 638, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.681
# Episode 639, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.681
# Episode 640, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.680
# Episode 641, Total Reward: 27.00, Lines Cleared: 0, Epsilon: 0.680
# Episode 642, Total Reward: 29.00, Lines Cleared: 1, Epsilon: 0.679
# Episode 643, Total Reward: 12.00, Lines Cleared: 0, Epsilon: 0.679
# Episode 644, Total Reward: 45.00, Lines Cleared: 2, Epsilon: 0.678
# Episode 645, Total Reward: 40.00, Lines Cleared: 1, Epsilon: 0.678
# Episode 646, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.677
# Episode 647, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.677
# Episode 648, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.676
# Episode 649, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.676
# Episode 650, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.675
# Episode 651, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.675
# Episode 652, Total Reward: 14.00, Lines Cleared: 0, Epsilon: 0.674
# Episode 653, Total Reward: 34.00, Lines Cleared: 1, Epsilon: 0.674
# Episode 654, Total Reward: 35.00, Lines Cleared: 1, Epsilon: 0.673
# Episode 655, Total Reward: 11.00, Lines Cleared: 0, Epsilon: 0.673
# Episode 656, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.672
# Episode 657, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.672
# Episode 658, Total Reward: 27.00, Lines Cleared: 0, Epsilon: 0.671
# Episode 659, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.671
# Episode 660, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.670
# Episode 661, Total Reward: 34.00, Lines Cleared: 1, Epsilon: 0.670
# Episode 662, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.669
# Episode 663, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.669
# Episode 664, Total Reward: 15.00, Lines Cleared: 0, Epsilon: 0.668
# Episode 665, Total Reward: 35.00, Lines Cleared: 1, Epsilon: 0.668
# Episode 666, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.667
# Episode 667, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.667
# Episode 668, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.666
# Episode 669, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.666
# Episode 670, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.665
# Episode 671, Total Reward: 21.00, Lines Cleared: 0, Epsilon: 0.665
# Episode 672, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.664
# Episode 673, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.664
# Episode 674, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.663
# Episode 675, Total Reward: 27.00, Lines Cleared: 0, Epsilon: 0.663
# Episode 676, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.662
# Episode 677, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.662
# Episode 678, Total Reward: 29.00, Lines Cleared: 0, Epsilon: 0.661
# Episode 679, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.661
# Episode 680, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.660
# Episode 681, Total Reward: 33.00, Lines Cleared: 1, Epsilon: 0.660
# Episode 682, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.659
# Episode 683, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.659
# Episode 684, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.658
# Episode 685, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.658
# Episode 686, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.657
# Episode 687, Total Reward: 27.00, Lines Cleared: 0, Epsilon: 0.657
# Episode 688, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.656
# Episode 689, Total Reward: 40.00, Lines Cleared: 1, Epsilon: 0.656
# Episode 690, Total Reward: 13.00, Lines Cleared: 0, Epsilon: 0.655
# Episode 691, Total Reward: 17.00, Lines Cleared: 0, Epsilon: 0.655
# Episode 692, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.654
# Episode 693, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.654
# Episode 694, Total Reward: 16.00, Lines Cleared: 0, Epsilon: 0.653
# Episode 695, Total Reward: 34.00, Lines Cleared: 1, Epsilon: 0.653
# Episode 696, Total Reward: 30.00, Lines Cleared: 1, Epsilon: 0.652
# Episode 697, Total Reward: 40.00, Lines Cleared: 1, Epsilon: 0.652
# Episode 698, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.651
# Episode 699, Total Reward: 23.00, Lines Cleared: 0, Epsilon: 0.651
# Episode 700, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.650
# Episode 701, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.650
# Episode 702, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.649
# Episode 703, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.649
# Episode 704, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.648
# Episode 705, Total Reward: 34.00, Lines Cleared: 1, Epsilon: 0.648
# Episode 706, Total Reward: 18.00, Lines Cleared: 0, Epsilon: 0.647
# Episode 707, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.647
# Episode 708, Total Reward: 22.00, Lines Cleared: 0, Epsilon: 0.646
# Episode 709, Total Reward: 36.00, Lines Cleared: 1, Epsilon: 0.646
# Episode 710, Total Reward: 19.00, Lines Cleared: 0, Epsilon: 0.645
# Episode 711, Total Reward: 20.00, Lines Cleared: 0, Epsilon: 0.645
# Episode 712, Total Reward: 36.00, Lines Cleared: 1, Epsilon: 0.644
# Episode 713, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.644
# Episode 714, Total Reward: 33.00, Lines Cleared: 1, Epsilon: 0.643
# Episode 715, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.643
# Episode 716, Total Reward: 37.00, Lines Cleared: 1, Epsilon: 0.642
# ...
# Episode 2269, Total Reward: 310.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2270, Total Reward: 935.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2271, Total Reward: 1527.00, Lines Cleared: 18, Epsilon: 0.001
# Episode 2272, Total Reward: 764.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2273, Total Reward: 681.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2274, Total Reward: 124.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2275, Total Reward: 129.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2276, Total Reward: 474.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2277, Total Reward: 1106.00, Lines Cleared: 13, Epsilon: 0.001
# Episode 2278, Total Reward: 130.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2279, Total Reward: 49.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2280, Total Reward: 226.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2281, Total Reward: 244.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2282, Total Reward: 207.00, Lines Cleared: 9, Epsilon: 0.001
# Episode 2283, Total Reward: 401.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2284, Total Reward: 157.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2285, Total Reward: 693.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2286, Total Reward: 147.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2287, Total Reward: 856.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2288, Total Reward: 317.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2289, Total Reward: 270.00, Lines Cleared: 9, Epsilon: 0.001
# Episode 2290, Total Reward: 119.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2291, Total Reward: 379.00, Lines Cleared: 13, Epsilon: 0.001
# Episode 2292, Total Reward: 400.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2293, Total Reward: 137.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2294, Total Reward: 245.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2295, Total Reward: 835.00, Lines Cleared: 11, Epsilon: 0.001
# Episode 2296, Total Reward: 920.00, Lines Cleared: 13, Epsilon: 0.001
# Episode 2297, Total Reward: 193.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2298, Total Reward: 128.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2299, Total Reward: 99.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2300, Total Reward: 141.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2301, Total Reward: 309.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2302, Total Reward: 34.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2303, Total Reward: 126.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2304, Total Reward: 123.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2305, Total Reward: 184.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2306, Total Reward: 157.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2307, Total Reward: 60.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2308, Total Reward: 801.00, Lines Cleared: 9, Epsilon: 0.001
# Episode 2309, Total Reward: 692.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2310, Total Reward: 724.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2311, Total Reward: 40.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2312, Total Reward: 58.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2313, Total Reward: 114.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2314, Total Reward: 158.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2315, Total Reward: 1334.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2316, Total Reward: 69.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2317, Total Reward: 1154.00, Lines Cleared: 17, Epsilon: 0.001
# Episode 2318, Total Reward: 37.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2319, Total Reward: 387.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2320, Total Reward: 115.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2321, Total Reward: 446.00, Lines Cleared: 9, Epsilon: 0.001
# Episode 2322, Total Reward: 1347.00, Lines Cleared: 32, Epsilon: 0.001
# Episode 2323, Total Reward: 221.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2324, Total Reward: 297.00, Lines Cleared: 11, Epsilon: 0.001
# Episode 2325, Total Reward: 378.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2326, Total Reward: 480.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2327, Total Reward: 576.00, Lines Cleared: 14, Epsilon: 0.001
# Episode 2328, Total Reward: 258.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2329, Total Reward: 475.00, Lines Cleared: 11, Epsilon: 0.001
# Episode 2330, Total Reward: 322.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2331, Total Reward: 131.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2332, Total Reward: 43.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2333, Total Reward: 51.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2334, Total Reward: 694.00, Lines Cleared: 14, Epsilon: 0.001
# Episode 2335, Total Reward: 551.00, Lines Cleared: 12, Epsilon: 0.001
# Episode 2336, Total Reward: 50.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2337, Total Reward: 334.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2338, Total Reward: 220.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2339, Total Reward: 61.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2340, Total Reward: 390.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2341, Total Reward: 30.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2342, Total Reward: 33.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2343, Total Reward: 320.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2344, Total Reward: 122.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2345, Total Reward: 403.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2346, Total Reward: 1315.00, Lines Cleared: 20, Epsilon: 0.001
# Episode 2347, Total Reward: 134.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2348, Total Reward: 140.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2349, Total Reward: 793.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2350, Total Reward: 50.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2351, Total Reward: 97.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2352, Total Reward: 111.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2353, Total Reward: 53.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2354, Total Reward: 183.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2355, Total Reward: 38.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2356, Total Reward: 125.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2357, Total Reward: 407.00, Lines Cleared: 15, Epsilon: 0.001
# Episode 2358, Total Reward: 967.00, Lines Cleared: 12, Epsilon: 0.001
# Episode 2359, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2360, Total Reward: 317.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2361, Total Reward: 157.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2362, Total Reward: 60.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2363, Total Reward: 138.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2364, Total Reward: 61.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2365, Total Reward: 86.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2366, Total Reward: 220.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2367, Total Reward: 303.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2368, Total Reward: 74.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2369, Total Reward: 421.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2370, Total Reward: 29.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2371, Total Reward: 320.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2372, Total Reward: 210.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2373, Total Reward: 117.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2374, Total Reward: 40.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2375, Total Reward: 26.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2376, Total Reward: 338.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2377, Total Reward: 995.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2378, Total Reward: 137.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2379, Total Reward: 152.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2380, Total Reward: 24.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2381, Total Reward: 646.00, Lines Cleared: 15, Epsilon: 0.001
# Episode 2382, Total Reward: 111.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2383, Total Reward: 62.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2384, Total Reward: 110.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2385, Total Reward: 72.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2386, Total Reward: 109.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2387, Total Reward: 224.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2388, Total Reward: 42.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2389, Total Reward: 113.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2390, Total Reward: 111.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2391, Total Reward: 86.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2392, Total Reward: 115.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2393, Total Reward: 114.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2394, Total Reward: 281.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2395, Total Reward: 404.00, Lines Cleared: 15, Epsilon: 0.001
# Episode 2396, Total Reward: 590.00, Lines Cleared: 20, Epsilon: 0.001
# Episode 2397, Total Reward: 170.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2398, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2399, Total Reward: 332.00, Lines Cleared: 14, Epsilon: 0.001
# Episode 2400, Total Reward: 71.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2401, Total Reward: 160.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2402, Total Reward: 98.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2403, Total Reward: 36.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2404, Total Reward: 537.00, Lines Cleared: 16, Epsilon: 0.001
# Episode 2405, Total Reward: 131.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2406, Total Reward: 59.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2407, Total Reward: 367.00, Lines Cleared: 12, Epsilon: 0.001
# Episode 2408, Total Reward: 330.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2409, Total Reward: 78.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2410, Total Reward: 196.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2411, Total Reward: 158.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2412, Total Reward: 196.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2413, Total Reward: 35.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2414, Total Reward: 173.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2415, Total Reward: 48.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2416, Total Reward: 733.00, Lines Cleared: 22, Epsilon: 0.001
# Episode 2417, Total Reward: 228.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2418, Total Reward: 233.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2419, Total Reward: 272.00, Lines Cleared: 9, Epsilon: 0.001
# Episode 2420, Total Reward: 271.00, Lines Cleared: 14, Epsilon: 0.001
# Episode 2421, Total Reward: 178.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2422, Total Reward: 914.00, Lines Cleared: 17, Epsilon: 0.001
# Episode 2423, Total Reward: 184.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2424, Total Reward: 157.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2425, Total Reward: 70.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2426, Total Reward: 173.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2427, Total Reward: 269.00, Lines Cleared: 9, Epsilon: 0.001
# Episode 2428, Total Reward: 204.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2429, Total Reward: 131.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2430, Total Reward: 224.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2431, Total Reward: 395.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2432, Total Reward: 158.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2433, Total Reward: 567.00, Lines Cleared: 23, Epsilon: 0.001
# Episode 2434, Total Reward: 193.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2435, Total Reward: 256.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2436, Total Reward: 146.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2437, Total Reward: 64.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2438, Total Reward: 764.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2439, Total Reward: 712.00, Lines Cleared: 20, Epsilon: 0.001
# Episode 2440, Total Reward: 775.00, Lines Cleared: 11, Epsilon: 0.001
# Episode 2441, Total Reward: 138.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2442, Total Reward: 47.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2443, Total Reward: 415.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2444, Total Reward: 220.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2445, Total Reward: 369.00, Lines Cleared: 12, Epsilon: 0.001
# Episode 2446, Total Reward: 110.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2447, Total Reward: 159.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2448, Total Reward: 97.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2449, Total Reward: 154.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2450, Total Reward: 282.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2451, Total Reward: 145.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2452, Total Reward: 173.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2453, Total Reward: 122.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2454, Total Reward: 98.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2455, Total Reward: 195.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2456, Total Reward: 210.00, Lines Cleared: 9, Epsilon: 0.001
# Episode 2457, Total Reward: 171.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2458, Total Reward: 352.00, Lines Cleared: 11, Epsilon: 0.001
# Episode 2459, Total Reward: 340.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2460, Total Reward: 98.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2461, Total Reward: 96.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2462, Total Reward: 221.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2463, Total Reward: 332.00, Lines Cleared: 9, Epsilon: 0.001
# Episode 2464, Total Reward: 245.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2465, Total Reward: 43.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2466, Total Reward: 196.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2467, Total Reward: 34.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2468, Total Reward: 538.00, Lines Cleared: 11, Epsilon: 0.001
# Episode 2469, Total Reward: 34.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2470, Total Reward: 113.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2471, Total Reward: 254.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2472, Total Reward: 342.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2473, Total Reward: 403.00, Lines Cleared: 10, Epsilon: 0.001
# Episode 2474, Total Reward: 380.00, Lines Cleared: 13, Epsilon: 0.001
# Episode 2475, Total Reward: 25.00, Lines Cleared: 0, Epsilon: 0.001
# Episode 2476, Total Reward: 183.00, Lines Cleared: 7, Epsilon: 0.001
# Episode 2477, Total Reward: 1039.00, Lines Cleared: 13, Epsilon: 0.001
# Episode 2478, Total Reward: 194.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2479, Total Reward: 267.00, Lines Cleared: 9, Epsilon: 0.001
# Episode 2480, Total Reward: 197.00, Lines Cleared: 8, Epsilon: 0.001
# Episode 2481, Total Reward: 40.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2482, Total Reward: 87.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2483, Total Reward: 208.00, Lines Cleared: 9, Epsilon: 0.001
# Episode 2484, Total Reward: 109.00, Lines Cleared: 6, Epsilon: 0.001
# Episode 2485, Total Reward: 57.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2486, Total Reward: 150.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2487, Total Reward: 138.00, Lines Cleared: 4, Epsilon: 0.001
# Episode 2488, Total Reward: 207.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2489, Total Reward: 1171.00, Lines Cleared: 23, Epsilon: 0.001
# Episode 2490, Total Reward: 72.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2491, Total Reward: 48.00, Lines Cleared: 1, Epsilon: 0.001
# Episode 2492, Total Reward: 61.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2493, Total Reward: 120.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2494, Total Reward: 220.00, Lines Cleared: 5, Epsilon: 0.001
# Episode 2495, Total Reward: 307.00, Lines Cleared: 12, Epsilon: 0.001
# Episode 2496, Total Reward: 135.00, Lines Cleared: 3, Epsilon: 0.001
# Episode 2497, Total Reward: 59.00, Lines Cleared: 2, Epsilon: 0.001
# Episode 2498, Total Reward: 355.00, Lines Cleared: 16, Epsilon: 0.001
# Episode 2499, Total Reward: 721.00, Lines Cleared: 26, Epsilon: 0.001

# %%
# Plot training results
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.plot(history)
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("CNN DQN - Reward History")
plt.grid(True)

plt.subplot(1, 3, 2)
plt.plot(lines)
plt.xlabel("Episode")
plt.ylabel("Lines Cleared")
plt.title("CNN DQN - Lines Cleared")
plt.grid(True)

plt.subplot(1, 3, 3)
# Moving average for smoother visualization
window = 100
if len(history) >= window:
    moving_avg = np.convolve(history, np.ones(window)/window, mode='valid')
    plt.plot(range(window-1, len(history)), moving_avg)
    plt.xlabel("Episode")
    plt.ylabel("Moving Average Reward")
    plt.title(f"CNN DQN - Moving Average (window={window})")
    plt.grid(True)

plt.tight_layout()
plt.show()

# Print final statistics
print("\n📊 Final Training Statistics:")
print(f"Total Episodes: {len(history)}")
print(f"Average Reward (last 100): {np.mean(history[-100:]):.2f}")
print(f"Best Reward: {np.max(history):.2f}")
print(f"Total Lines Cleared: {sum(lines)}")
print(f"Average Lines/Episode: {np.mean(lines):.2f}")
print(f"Max Lines in Single Episode: {np.max(lines)}")
# Out:
# 📊 Final Training Statistics:
# Total Episodes: 2500
# Average Reward (last 100): 242.40
# Best Reward: 2546.00
# Total Lines Cleared: 6479
# Average Lines/Episode: 2.59
# Max Lines in Single Episode: 38

# %%
# Evaluate trained CNN DQN and save gameplay video
device = next(q_net.parameters()).device
env = make_custom_tetris_env(render_mode="rgb_array")
video_path = "tetris_cnn_eval.mp4"
writer = imageio.get_writer(video_path, fps=30)
episodes = 10

print(f"\n🎮 Evaluating trained agent for {episodes} episodes on {device}...\n")

for ep in range(episodes):
    state, info = env.reset()
    done = False
    total_reward = 0
    lines_cleared = 0

    while not done:
        # Extract features for all possible placements
        # state shape: (N, H, W) -> features shape: (N, 4)
        features = extract_features_from_observations(state, info).to(device)

        # Compute Q-values for all placements
        with torch.no_grad():
            q_values = q_net(features)  # Shape: (N,)

        # Legal action masking
        legal_actions = info.get("action_mask", None)
        if legal_actions is not None:
            if hasattr(legal_actions, "numpy"):
                legal_actions = legal_actions.numpy()
            legal_indices = np.where(legal_actions)[0]
            legal_tensor = torch.tensor(legal_actions, dtype=torch.bool, device=device)
            masked_q_values = q_values.clone()
            masked_q_values[~legal_tensor] = -float("inf")
            action = masked_q_values.argmax().item()
        else:
            action = q_values.argmax().item()

        # Step environment
        next_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        total_reward += reward
        lines_cleared += info.get("lines_cleared", 0)
        state = next_state

        # Render frame and append to video
        frame = env.render()
        writer.append_data(np.asarray(frame).astype(np.uint8))

    print(f"Episode {ep+1}/{episodes} | Total Reward: {total_reward:.2f} | Lines Cleared: {lines_cleared}")

writer.close()
env.close()
print(f"\n🎥 Video saved to {video_path}")
# Out:
# 🎮 Evaluating trained agent for 10 episodes on cuda:0...
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (340, 240) to (352, 240) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Episode 1/10 | Total Reward: 384.00 | Lines Cleared: 20
# Episode 2/10 | Total Reward: 201.00 | Lines Cleared: 10
# Episode 3/10 | Total Reward: 56.00 | Lines Cleared: 2
# Episode 4/10 | Total Reward: 193.00 | Lines Cleared: 11
# Episode 5/10 | Total Reward: 85.00 | Lines Cleared: 4
# Episode 6/10 | Total Reward: 117.00 | Lines Cleared: 5
# Episode 7/10 | Total Reward: 167.00 | Lines Cleared: 9
# Episode 8/10 | Total Reward: 275.00 | Lines Cleared: 16
# Episode 9/10 | Total Reward: 84.00 | Lines Cleared: 4
# Episode 10/10 | Total Reward: 182.00 | Lines Cleared: 10
#
# 🎥 Video saved to tetris_cnn_eval.mp4

# %%
Video("tetris_cnn_eval.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
